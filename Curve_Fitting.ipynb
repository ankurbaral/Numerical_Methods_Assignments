# %% [markdown]
# # Curve Fitting

# %% [markdown]
# Q1. 11. Using least square method to fit the straight line 𝑦 = 𝑎<sub>0</sub> + 𝑎<sub>1</sub>𝑥 to the following data:
# <strong>Find the data in Python_Assignment-II.pdf</strong> <br>
# Using this fit estimate the value of 𝑦 at 𝑥 = 2.5

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x):
    return a0+a1*x
x_values = np.arange(start = 1, stop = 7 )
y_values = np.array([2.4, 3.1, 3.5, 4.2, 5.0, 6.0])

n = len(x_values)

sumX = np.sum(x_values)
sumY = np.sum(y_values)
sumXY = np.sum(x_values*y_values)
sumXsqr = np.sum(x_values**2)

# a1 = (n/(n-1))*((sumXY - (sumY*sumX))/sumXsqr)
a1 = (n * sumXY - sumX * sumY) / (n * sumXsqr - sumX ** 2)
a0 = (sumY - (a1*sumX))/n

y = a0+a1*x_values
plt.scatter(x_values,y_values)
plt.plot(x_values, f(x_values), color = 'red')



#%matplotlib inline
#plt.scatter(x_values, y_values)
